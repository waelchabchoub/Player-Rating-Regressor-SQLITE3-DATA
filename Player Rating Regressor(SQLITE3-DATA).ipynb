# %%
import sqlite3
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # CONNECT SQLITE DATA BASE AND READ IT

# %%
cnx = sqlite3.connect('./database.sqlite')
data = pd.read_sql_query('SELECT* FROM Player_Attributes',cnx)

# %%
data.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0  ...    54.0       48.0     65.0             69.0            69.0
# 1  ...    54.0       48.0     65.0             69.0            69.0
# 2  ...    54.0       48.0     65.0             66.0            69.0
# 3  ...    53.0       47.0     62.0             63.0            66.0
# 4  ...    53.0       47.0     62.0             63.0            66.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
# 2        6.0         11.0        10.0             8.0          8.0
# 3        5.0         10.0         9.0             7.0          7.0
# 4        5.0         10.0         9.0             7.0          7.0
#
# [5 rows x 42 columns]

# %%
df_info= pd.DataFrame({"Dtype": data.dtypes, "Unique": data.nunique(), "Missing%": (data.isnull().sum()/data.shape[0])*100})
df_info
# Out:
#                        Dtype  Unique  Missing%
# id                     int64  183978  0.000000
# player_fifa_api_id     int64   11062  0.000000
# player_api_id          int64   11060  0.000000
# date                  object     197  0.000000
# overall_rating       float64      61  0.454402
# potential            float64      56  0.454402
# preferred_foot        object       2  0.454402
# attacking_work_rate   object       8  1.755645
# defensive_work_rate   object      19  0.454402
# crossing             float64      95  0.454402
# finishing            float64      97  0.454402
# heading_accuracy     float64      96  0.454402
# short_passing        float64      95  0.454402
# volleys              float64      93  1.474633
# dribbling            float64      97  0.454402
# curve                float64      92  1.474633
# free_kick_accuracy   float64      97  0.454402
# long_passing         float64      95  0.454402
# ball_control         float64      93  0.454402
# acceleration         float64      86  0.454402
# sprint_speed         float64      85  0.454402
# agility              float64      81  1.474633
# reactions            float64      78  0.454402
# balance              float64      81  1.474633
# shot_power           float64      96  0.454402
# jumping              float64      79  1.474633
# stamina              float64      84  0.454402
# strength             float64      82  0.454402
# long_shots           float64      96  0.454402
# aggression           float64      91  0.454402
# interceptions        float64      96  0.454402
# positioning          float64      95  0.454402
# vision               float64      97  1.474633
# penalties            float64      94  0.454402
# marking              float64      95  0.454402
# standing_tackle      float64      95  0.454402
# sliding_tackle       float64      94  1.474633
# gk_diving            float64      93  0.454402
# gk_handling          float64      90  0.454402
# gk_kicking           float64      97  0.454402
# gk_positioning       float64      94  0.454402
# gk_reflexes          float64      92  0.454402

# %% [markdown]
# # DATA PROCESSING

# %%
data.columns
# Out:
# Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
clean_data = data.dropna()
y = clean_data[['overall_rating']]
x =clean_data[['potential','crossing','finishing','heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
       'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
       'gk_reflexes']]

# %% [markdown]
# # SPLIT THE DATA INTO TRAIN AND TEST

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=324)

# %% [markdown]
# # TRAIN MODEL USING LINEAR REGRESSION

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # PREDICTION

# %%
predictions = regressor.predict(x_test)

# %%
print('The predicted values:{}\n Y_test = {}'.format(predictions[:15],y_test[:15]))
# Out:
# The predicted values:[[66.51284879]
#  [79.77234615]
#  [66.57371825]
#  [74.99042163]
#  [66.20353346]
#  [62.79820836]
#  [76.21901664]
#  [69.36647267]
#  [66.93368892]
#  [73.98655725]
#  [62.67862312]
#  [74.71147439]
#  [68.3737291 ]
#  [67.8427546 ]
#  [81.01055706]]
#  Y_test =         overall_rating
# 35543             66.0
# 28735             83.0
# 168029            65.0
# 138117            74.0
# 123316            65.0
# 8946              63.0
# 17365             78.0
# 94431             67.0
# 55237             64.0
# 130295            67.0
# 110857            65.0
# 178068            76.0
# 60797             69.0
# 98489             69.0
# 30686             80.0

# %% [markdown]
# # RMSE

# %%
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=predictions))
print('l\erreur quadratique :'+ str(rmse))
# Out:
# l\erreur quadratique :2.8053030468552094

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor
tree_regressor = DecisionTreeRegressor(max_depth=20)
tree_regressor.fit(x_train,y_train)
tree_predictions = tree_regressor.predict(x_test)
tree_rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=tree_predictions))
print('l\erreur quadratique :'+ str(tree_rmse))
# Out:
# l\erreur quadratique :1.4608824406710466

# %% [markdown]
# # in this dataset RegressorTree worked better than LinearRegressor
